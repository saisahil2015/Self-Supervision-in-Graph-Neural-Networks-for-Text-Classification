# %%
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from tree import *
from torch.nn.utils.rnn import pad_sequence
import argparse
import codecs
import json
import linecache
import logging
import os
import pickle
import random
import sys
from collections import Counter, defaultdict
from copy import copy, deepcopy

import nltk
import numpy as np
import simplejson as json
import torch
from allennlp.modules.elmo import batch_to_ids
from lxml import etree
from nltk import word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from torch.utils.data import DataLoader, Dataset


import warnings
warnings.filterwarnings('always')

# %%
def set_seed(args):
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed_all(args.seed)

# %%
def read_sentence_depparsed(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
        return data


def get_dataset(dataset_name):
    rest_train = 'data/semeval14/Restaurants_Train_v2_biaffine_depparsed_with_energy.json'
    rest_test = 'data/semeval14/Restaurants_Test_Gold_biaffine_depparsed_with_energy.json'

    laptop_train = 'data/semeval14/Laptop_Train_v2_biaffine_depparsed.json'
    laptop_test = 'data/semeval14/Laptops_Test_Gold_biaffine_depparsed.json'

    twitter_train = 'data/twitter/train_biaffine.json'
    twitter_test = 'data/twitter/test_biaffine.json'

    ds_train = {'rest': rest_train,
                'laptop': laptop_train, 
                'twitter': twitter_train}
    ds_test = {'rest': rest_test,
               'laptop': laptop_test, 
               'twitter': twitter_test}

    train = list(read_sentence_depparsed(ds_train[dataset_name]))
    test = list(read_sentence_depparsed(ds_test[dataset_name]))
    
    print("Read {} Train set: {}".format(dataset_name, len(train)))
    print("Read {} Test set: {}".format(dataset_name, len(test)))

    return train, test

# %%
def get_rolled_and_unrolled_data(input_data, args):
    # A hand-picked set of part of speech tags that we see contributes to ABSA.
    all_unrolled = []
    # Make sure the tree is successfully built.
    zero_dep_counter = 0

    # Sentiment counters
    total_counter = defaultdict(int)
    sentiments_lookup = {'negative': 0, 'positive': 1, 'neutral': 2}

    # for seeking 'but' examples
    for e in input_data:
        e['tokens'] = [x.lower() for x in e['tokens']]
        aspects = []
        sentiments = []
        froms = []
        tos = []
        dep_tags = []
        dep_index = []
        dep_dirs = []

        # Classify based on POS-tags
        pos_class = e['tags']

        # Iterate through aspects in a sentence and reshape the dependency tree.
        for i in range(len(e['aspect_sentiment'])):
            aspect = e['aspect_sentiment'][i][0].lower()
            # We would tokenize the aspect while at it.
            aspect = word_tokenize(aspect)
            sentiment = sentiments_lookup[e['aspect_sentiment'][i][1]]
            frm = e['from_to'][i][0]
            to = e['from_to'][i][1]

            aspects.append(aspect)
            sentiments.append(sentiment)
            froms.append(frm)
            tos.append(to)

            # Center on the aspect.
            dep_tag, dep_idx, dep_dir = reshape_dependency_tree(frm, to, e['dependencies'], tokens=e['tokens'], max_hop=args.max_hop)

            # Because of tokenizer differences, aspect opsitions are off, so we find the index and try again.
            if len(dep_tag) == 0:
                zero_dep_counter += 1
                as_sent = e['aspect_sentiment'][i][0].split()
                as_start = e['tokens'].index(as_sent[0])
                # print(e['tokens'], e['aspect_sentiment'], e['dependencies'],as_sent[0])
                as_end = e['tokens'].index(
                    as_sent[-1]) if len(as_sent) > 1 else as_start + 1
                print("Debugging: as_start as_end ", as_start, as_end)
                dep_tag, dep_idx, dep_dir = reshape_dependency_tree(as_start, as_end, e['dependencies'], tokens=e['tokens'], max_hop=args.max_hop)
                if len(dep_tag) == 0:  # for debugging
                    print("Debugging: zero_dep",
                          e['aspect_sentiment'][i][0], e['tokens'])
                    print("Debugging: ". e['dependencies'])
                else:
                    zero_dep_counter -= 1

            dep_tags.append(dep_tag)
            dep_index.append(dep_idx)
            dep_dirs.append(dep_dir)

            total_counter[e['aspect_sentiment'][i][1]] += 1

            # Unrolling
            all_unrolled.append(
                {'sentence': e['tokens'], 'tags': e['tags'], 'pos_class': pos_class, 'aspect': aspect, 'sentiment': sentiment,
                    'predicted_dependencies': e['predicted_dependencies'], 'predicted_heads': e['predicted_heads'],
                 'from': frm, 'to': to, 'dep_tag': dep_tag, 'dep_idx': dep_idx, 'dep_dir':dep_dir,'dependencies': e['dependencies']})

    return all_unrolled

# %%
def load_datasets_and_vocabs(args):
    train, test = get_dataset(args.dataset_name)
    # Our model takes unrolled data, currently we don't consider the MAMS cases(future experiments)
    train_all_unrolled = get_rolled_and_unrolled_data(train, args)
    test_all_unrolled = get_rolled_and_unrolled_data(test, args)
    print("Size of the train dataset: {}".format(len(train_all_unrolled)))
    print("Size of the test dataset: {}".format(len(test_all_unrolled)))

    # Build word vocabulary(part of speech, dep_tag) and save pickles.
    word_vecs, word_vocab, dep_tag_vocab, pos_tag_vocab = load_and_cache_vocabs(train_all_unrolled+test_all_unrolled, args)

    embedding = torch.from_numpy(np.asarray(word_vecs, dtype=np.float32))
    args.glove_embedding = embedding

    train_dataset = ASBA_Depparsed_Dataset(train_all_unrolled, args, word_vocab, dep_tag_vocab, pos_tag_vocab)
    test_dataset = ASBA_Depparsed_Dataset(test_all_unrolled, args, word_vocab, dep_tag_vocab, pos_tag_vocab)

    return train_dataset, test_dataset, word_vocab, dep_tag_vocab, pos_tag_vocab



def reshape_dependency_tree(as_start, as_end, dependencies, tokens=None, max_hop = 5):
    '''
    Adding multi hops
    This function is at the core of our algo, it reshape the dependency tree and center on the aspect.
    In open-sourced edition, I choose not to take energy(the soft prediction of dependency from parser)
    into consideration. For it requires tweaking allennlp's source code, and the energy is space-consuming.
    And there are no significant difference in performance between the soft and the hard(with non-connect) version.

    '''
    dep_tag = []
    dep_idx = []
    dep_dir = []
    # 1 hop

    for i in range(as_start, as_end):
        for dep in dependencies:
            if i == dep[1] - 1:
                # not root, not aspect
                if (dep[2] - 1 < as_start or dep[2] - 1 >= as_end) and dep[2] != 0 and dep[2] - 1 not in dep_idx:
                    if str(dep[0]) != 'punct':  # and tokens[dep[2] - 1] not in stopWords
                        dep_tag.append(dep[0])
                        dep_dir.append(1)
                    else:
                        dep_tag.append('<pad>')
                        dep_dir.append(0)
                    dep_idx.append(dep[2] - 1)
            elif i == dep[2] - 1:
                # not root, not aspect
                if (dep[1] - 1 < as_start or dep[1] - 1 >= as_end) and dep[1] != 0 and dep[1] - 1 not in dep_idx:
                    if str(dep[0]) != 'punct':  # and tokens[dep[1] - 1] not in stopWords
                        dep_tag.append(dep[0])
                        dep_dir.append(2)
                    else:
                        dep_tag.append('<pad>')
                        dep_dir.append(0)
                    dep_idx.append(dep[1] - 1)

    # add aspect and index, to make sure length matches len(tokens)
    for idx, token in enumerate(tokens):
        if idx not in dep_idx:
            dep_tag.append('<pad>')
            dep_dir.append(0)
            dep_idx.append(idx)

    index = [i[0] for i in sorted(enumerate(dep_idx), key=lambda x:x[1])]
    dep_tag = [dep_tag[i] for i in index]
    dep_idx = [dep_idx[i] for i in index]
    dep_dir = [dep_dir[i] for i in index]

    assert len(tokens) == len(dep_idx), 'length wrong'
    return dep_tag, dep_idx, dep_dir




import pickle

def load_and_cache_vocabs(data, args):
    '''
    Build vocabulary of words, part of speech tags, dependency tags and cache them.
    Load glove embedding if needed.'''
    
    if not True:
        with open("cached_word_vocab.pkl", 'rb') as f:
            word_vocab = pickle.load(f)
        
        with open("cached_word_vecs.pkl", 'rb') as f:
            word_vecs = pickle.load(f)
        
        with open("cached_dep_tag_vocab.pkl", 'rb') as f:
            dep_tag_vocab = pickle.load(f)
            
        with open("cached_pos_tag_vocab.pkl", 'rb') as f:
            pos_tag_vocab = pickle.load(f)
        #pos_tag_vocab = build_pos_tag_vocab(data, min_freq=0)
        
    
    else:
        
        # Build or load word vocab and glove embeddings.
        word_vocab = build_text_vocab(data)
        print('Word vocab size: {}'.format(word_vocab['len']))
        #with open("cached_word_vocab.pkl", 'wb') as f:
            #pickle.dump(word_vocab, f, -1)
        
        word_vecs = load_glove_embedding(word_vocab['itos'], args.glove_dir, 0.25, args.embedding_dim)
        #print('Word vecs size')
        #with open("cached_word_vecs.pkl", 'wb') as f:
            #pickle.dump(word_vecs, f, -1)
            
        # Build vocab of dependency tags
        dep_tag_vocab = build_dep_tag_vocab(data, min_freq=0)
        #print('dep_tag_vocab size: {}'.format(dep_tag_vocab['len']))
        #with open("cached_dep_tag_vocab.pkl", 'wb') as f:
            #pickle.dump(dep_tag_vocab, f, -1)
            
        # Build vocab of part of speech tags.
        pos_tag_vocab = build_pos_tag_vocab(data, min_freq=0)
        #print('pos_tag_vocab size: {}'.format(pos_tag_vocab['len']))
        #with open("cached_pos_tag_vocab.pkl", 'wb') as f:
            #pickle.dump(pos_tag_vocab, f, -1)

    return word_vecs, word_vocab, dep_tag_vocab, pos_tag_vocab


def load_glove_embedding(word_list, glove_dir, uniform_scale, dimension_size):
    glove_words = []
    with open(os.path.join(glove_dir, 'glove.840B.300d.txt'), 'r', encoding="utf8") as fopen:
        for line in fopen:
            glove_words.append(line.strip().split(' ')[0])
    word2offset = {w: i for i, w in enumerate(glove_words)}
    word_vectors = []
    for word in word_list:
        if word in word2offset:
            line = linecache.getline(os.path.join(
                glove_dir, 'glove.840B.300d.txt'), word2offset[word]+1)
            assert(word == line[:line.find(' ')].strip())
            word_vectors.append(np.fromstring(
                line[line.find(' '):].strip(), sep=' ', dtype=np.float32))
        elif word == '<pad>':
            word_vectors.append(np.zeros(dimension_size, dtype=np.float32))
        else:
            word_vectors.append(
                np.random.uniform(-uniform_scale, uniform_scale, dimension_size))
    return word_vectors


def _default_unk_index():
    return 1


def build_text_vocab(data, vocab_size=100000, min_freq=2):
    counter = Counter()
    for d in data:
        s = d['sentence']
        counter.update(s)

    itos = ['[PAD]', '[UNK]']
    min_freq = max(min_freq, 1)

    # sort by frequency, then alphabetically
    words_and_frequencies = sorted(counter.items(), key=lambda tup: tup[0])
    words_and_frequencies.sort(key=lambda tup: tup[1], reverse=True)

    for word, freq in words_and_frequencies:
        if freq < min_freq or len(itos) == vocab_size:
            break
        itos.append(word)
    # stoi is simply a reverse dict for itos
    stoi = defaultdict(_default_unk_index)
    stoi.update({tok: i for i, tok in enumerate(itos)})

    return {'itos': itos, 'stoi': stoi, 'len': len(itos)}


def build_pos_tag_vocab(data, vocab_size=1000, min_freq=1):
    """
    Part of speech tags vocab.
    """
    counter = Counter()
    for d in data:
        tags = d['tags']
        counter.update(tags)

    itos = ['<pad>']
    min_freq = max(min_freq, 1)

    # sort by frequency, then alphabetically
    words_and_frequencies = sorted(counter.items(), key=lambda tup: tup[0])
    words_and_frequencies.sort(key=lambda tup: tup[1], reverse=True)

    for word, freq in words_and_frequencies:
        if freq < min_freq or len(itos) == vocab_size:
            break
        itos.append(word)
    # stoi is simply a reverse dict for itos
    stoi = defaultdict()
    stoi.update({tok: i for i, tok in enumerate(itos)})

    return {'itos': itos, 'stoi': stoi, 'len': len(itos)}



def build_dep_tag_vocab(data, vocab_size=1000, min_freq=0):
    counter = Counter()
    for d in data:
        tags = d['dep_tag']
        counter.update(tags)

    itos = ['<pad>', '<unk>']
    min_freq = max(min_freq, 1)

    # sort by frequency, then alphabetically
    words_and_frequencies = sorted(counter.items(), key=lambda tup: tup[0])
    words_and_frequencies.sort(key=lambda tup: tup[1], reverse=True)

    for word, freq in words_and_frequencies:
        if freq < min_freq or len(itos) == vocab_size:
            break
        if word == '<pad>':
            continue
        itos.append(word)
    # stoi is simply a reverse dict for itos
    stoi = defaultdict(_default_unk_index)
    stoi.update({tok: i for i, tok in enumerate(itos)})

    return {'itos': itos, 'stoi': stoi, 'len': len(itos)}


class ASBA_Depparsed_Dataset(Dataset):
    def __init__(self, data, args, word_vocab, dep_tag_vocab, pos_tag_vocab):
        self.data = data
        self.args = args
        self.word_vocab = word_vocab
        self.dep_tag_vocab = dep_tag_vocab
        self.pos_tag_vocab = pos_tag_vocab

        self.convert_features()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        items = e['dep_tag_ids'], e['pos_class'], e['text_len'], e['aspect_len'], e['sentiment'], e['dep_rel_ids'], e['predicted_heads'], e['aspect_position'], e['dep_dir_ids']
        non_bert_items = e['sentence_ids'], e['aspect_ids']
        items_tensor = non_bert_items + items
        items_tensor = tuple(torch.tensor(t) for t in items_tensor)

        return items_tensor

    

    def convert_features(self):
        '''
        Convert sentence, aspects, pos_tags, dependency_tags to ids.
        '''
        for i in range(len(self.data)):
       
            self.data[i]['sentence_ids'] = [self.word_vocab['stoi'][w] for w in self.data[i]['sentence']]
            self.data[i]['aspect_ids'] = [self.word_vocab['stoi'][w] for w in self.data[i]['aspect']]
           

            self.data[i]['text_len'] = len(self.data[i]['sentence'])
            self.data[i]['aspect_position'] = [0] * self.data[i]['text_len']
            try:  # find the index of aspect in sentence
                for j in range(self.data[i]['from'], self.data[i]['to']):
                    self.data[i]['aspect_position'][j] = 1
            except:
                for term in self.data[i]['aspect']:
                    self.data[i]['aspect_position'][self.data[i]
                                                    ['sentence'].index(term)] = 1

            self.data[i]['dep_tag_ids'] = [self.dep_tag_vocab['stoi'][w]
                                           for w in self.data[i]['dep_tag']]
            self.data[i]['dep_dir_ids'] = [idx
                                           for idx in self.data[i]['dep_dir']]
            self.data[i]['pos_class'] = [self.pos_tag_vocab['stoi'][w]
                                             for w in self.data[i]['tags']]
            self.data[i]['aspect_len'] = len(self.data[i]['aspect'])

            self.data[i]['dep_rel_ids'] = [self.dep_tag_vocab['stoi'][r]
                                           for r in self.data[i]['predicted_dependencies']]


def my_collate(batch):
    '''
    Pad sentence and aspect in a batch.
    Sort the sentences based on length.
    Turn all into tensors.
    '''
    sentence_ids, aspect_ids, dep_tag_ids, pos_class, text_len, aspect_len, sentiment, dep_rel_ids, dep_heads, aspect_positions, dep_dir_ids = zip(
        *batch)  # from Dataset.__getitem__()
    text_len = torch.tensor(text_len)
    aspect_len = torch.tensor(aspect_len)
    sentiment = torch.tensor(sentiment)

    # Pad sequences.
    sentence_ids = pad_sequence(
        sentence_ids, batch_first=True, padding_value=0)
    aspect_ids = pad_sequence(aspect_ids, batch_first=True, padding_value=0)
    aspect_positions = pad_sequence(
        aspect_positions, batch_first=True, padding_value=0)

    dep_tag_ids = pad_sequence(dep_tag_ids, batch_first=True, padding_value=0)
    dep_dir_ids = pad_sequence(dep_dir_ids, batch_first=True, padding_value=0)
    pos_class = pad_sequence(pos_class, batch_first=True, padding_value=0)

    dep_rel_ids = pad_sequence(dep_rel_ids, batch_first=True, padding_value=0)
    dep_heads = pad_sequence(dep_heads, batch_first=True, padding_value=0)

    # Sort all tensors based on text len.
    _, sorted_idx = text_len.sort(descending=True)
    sentence_ids = sentence_ids[sorted_idx]
    aspect_ids = aspect_ids[sorted_idx]
    aspect_positions = aspect_positions[sorted_idx]
    dep_tag_ids = dep_tag_ids[sorted_idx]
    dep_dir_ids = dep_dir_ids[sorted_idx]
    pos_class = pos_class[sorted_idx]
    text_len = text_len[sorted_idx]
    aspect_len = aspect_len[sorted_idx]
    sentiment = sentiment[sorted_idx]
    dep_rel_ids = dep_rel_ids[sorted_idx]
    dep_heads = dep_heads[sorted_idx]

    return sentence_ids, aspect_ids, dep_tag_ids, pos_class, text_len, aspect_len, sentiment, dep_rel_ids, dep_heads, aspect_positions, dep_dir_ids

# %%
def mask_logits(target, mask):
    return target * mask + (1 - mask) * (-1e30)

class Gating(nn.Module):
    def __init__(self, layer_num, dim):
        super().__init__()
        self.layer_num = layer_num
        self.linear = nn.ModuleList([nn.Linear(dim, dim) for _ in range(layer_num)])
        self.gate = nn.ModuleList([nn.Linear(dim, dim) for _ in range(layer_num)])

    def forward(self, x):
        for i in range(self.layer_num):
            gate = torch.sigmoid(self.gate[i](x))
            nonlinear = F.relu(self.linear[i](x))
            x = gate * nonlinear + (1 - gate) * x
        return x

class DotprodAttention(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, feature, dep_tags, dmask):
        '''
        C feature/context [N, L, D]
        Q dep_tags_v          [N, D]
        mask dmask          [N, L]
        '''

        Q = dep_tags
        Q = Q.unsqueeze(2)  # (N, D, 1)
        dot_prod = torch.bmm(feature, Q)  # (N, L, 1)
        dmask = dmask.unsqueeze(2)  # (N, D, 1)
        attention_weight = mask_logits(dot_prod, dmask)  # (N, L ,1)
        attention = F.softmax(attention_weight, dim=1)  # (N, L, 1)

        out = torch.bmm(feature.transpose(1, 2), attention)  # (N, D, 1)
        out = out.squeeze(2)
        out = torch.sigmoid(out)
        # (N, D), ([N, L]), (N, L, 1)
        return out

class RelationAttention(nn.Module):
    def __init__(self, in_dim = 300, hidden_dim = 64):
        # in_dim: the dimension fo query vector
        super().__init__()

        self.fc1 = nn.Linear(in_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, feature, dep_tags_v, dmask):
        '''
        C feature/context [N, L, D]
        Q dep_tags_v          [N, L, D]
        mask dmask          [N, L]
        '''
        Q = self.fc1(dep_tags_v)
        Q = self.relu(Q)
        Q = self.fc2(Q)  # (N, L, 1)
        Q = Q.squeeze(2)
        Q = F.softmax(mask_logits(Q, dmask), dim=1)

        Q = Q.unsqueeze(2)
        out = torch.bmm(feature.transpose(1, 2), Q)
        out = out.squeeze(2)
        # out = F.sigmoid(out)
        return out  # ([N, L])

# %%
class TextGraphAttentionNetwork(nn.Module):
    def __init__(self, args, dep_tag_num):
        super(TextGraphAttentionNetwork, self).__init__()
        self.args = args

        num_embeddings, embed_dim = args.glove_embedding.shape
        self.embed = nn.Embedding(num_embeddings, embed_dim)
        self.embed.weight = nn.Parameter(args.glove_embedding, requires_grad=False)
        self.dropout = nn.Dropout(args.dropout)
        self.tanh = nn.Tanh()
        self.gate = Gating(args.num_layers, args.embedding_dim)
        self.rnn = nn.GRU(input_size=args.embedding_dim, hidden_size=args.hidden_size, bidirectional=True, batch_first=True, num_layers=args.num_layers)
    
        self.gat = [DotprodAttention().to(args.device) for i in range(args.num_heads)]
        self.gat_dep = [RelationAttention(in_dim = args.embedding_dim).to(args.device) for i in range(args.num_heads)]
        
        last_hidden_size = args.hidden_size*4

        layers = [nn.Linear(last_hidden_size, args.final_hidden_size), nn.ReLU()]
        
        for _ in range(args.num_mlps-1):
            layers += [nn.Linear(args.final_hidden_size, args.final_hidden_size), nn.ReLU()]
            
        self.dep_embed = nn.Embedding(dep_tag_num, args.embedding_dim)
        gcn_input_dim = args.hidden_size * 2
        self.fc = nn.Linear(args.embedding_dim, 2*args.hidden_size)
        self.fcs = nn.Sequential(*layers)
        self.fc_final = nn.Linear(args.final_hidden_size, args.num_classes)
        self.linear = nn.Linear(gcn_input_dim, gcn_input_dim)

    def forward(self, sentence, aspect, pos_class, dep_tags, text_len, aspect_len, dep_rels, dep_heads, aspect_position, dep_dirs):

        '''
        Forward takes:
            sentence: sentence_id of size (batch_size, text_length)
            aspect: aspect_id of size (batch_size, aspect_length)
            pos_class: pos_tag_id of size (batch_size, text_length)
            dep_tags: dep_tag_id of size (batch_size, text_length)
            text_len: (batch_size,) length of each sentence
            aspect_len: (batch_size, ) aspect length of each sentence
            dep_rels: (batch_size, text_length) relation
            dep_heads: (batch_size, text_length) which node adjacent to that node
            aspect_position: (batch_size, text_length) mask, with the position of aspect as 1 and others as 0
            dep_dirs: (batch_size, text_length) the directions each node to the aspect
        '''
        fmask = (torch.zeros_like(sentence) != sentence).float()  # (N，L)
        feature = self.embed(sentence)  # (N, L, D)
        feature = self.dropout(feature)
        feature = self.gate(feature)
        feature = self.fc(feature) # (N,L,D)
        
        dep_feature = self.dep_embed(dep_tags) 
        dep_feature = self.gate(dep_feature)

        dep_out = [g(feature, dep_feature, fmask).unsqueeze(1) for g in self.gat_dep] #(N, 1, D) * num_heads
        dep_out = torch.cat(dep_out, dim = 1) # (N, H, D)
        dep_out = dep_out.mean(dim = 1) # (N, D)
        
        #print("Shape of the feature", feature.shape)
        #print("Shape of the dep_out", dep_out.shape)
        
        gat_out = self.linear(feature) # (N, L, D)
        #print("Shape of the gat_out right now", gat_out.shape)
        fmask = fmask.unsqueeze(2)
        gat_out = gat_out * fmask
        
        #print("Shape of the gat_out after fmask", gat_out.shape)
        gat_out = F.relu(torch.sum(gat_out, dim = 1)) # (N, D)
        #print("Shape of the gat_out", gat_out.shape)
        
        feature_out = torch.cat([dep_out,  gat_out], dim = 1) # (N, D')
       
        # feature_out = gat_out
        #############################################################################################
        x = self.dropout(feature_out)
        x = self.fcs(x)
        logit = self.fc_final(x)
        return logit

# %%
class Parameters:
    def __init__(self):
        pass 

args = Parameters()
 # Required parameters
args.dataset_name = 'rest' # 'rest' 'laptop' 'twitter'
args.output_dir = 'data/output-gcn'
args.num_classes = 3
args.cuda_id = '3'
args.seed = 2022

# Model parameters
args.glove_dir = 'glove'
args.num_layers = 2
args.max_hop = 4
args.num_heads = 6
args.dropout = 0
args.num_gcn_layers = 1
args.gc_mem_dim = 300

args.gcn_dropout = 0.2
# GAT
args.gat = True
args.gat_out = True


args.gat_attention_type = 'dotprod' # 'linear' 'dotprod' 'gcn'
args.embedding_type = 'glove' # 'glove' 'bert'
args.embedding_dim = 300
args.dep_relation_embed_dim = 300
args.hidden_size = 300
args.final_hidden_size = 300
args.num_mlps = 2
# Training parameters
args.per_gpu_train_batch_size = 16
args.per_gpu_eval_batch_size = 32
args.gradient_accumulation_steps = 2
args.learning_rate = 1e-3
args.weight_decay = 0.0
args.adam_epsilon = 1e-8
args.max_grad_norm = 1.0
args.num_train_epochs = 30
args.max_steps = -1
args.logging_steps = 50

import pickle

# %%
def get_input_from_batch(args, batch):
    # sentence_ids, aspect_ids, dep_tag_ids, pos_class, text_len, aspect_len, sentiment, dep_rel_ids, dep_heads, aspect_positions
    inputs = {  'sentence': batch[0],
                'aspect': batch[1], # aspect token
                'dep_tags': batch[2], # reshaped
                'pos_class': batch[3],
                'text_len': batch[4],
                'aspect_len': batch[5],
                'dep_rels': batch[7], # adj no-reshape
                'dep_heads': batch[8],
                'aspect_position': batch[9],
                'dep_dirs': batch[10]
                }
    labels = batch[6]

    return inputs, labels

def train(args, train_dataset, model, eval_dataset):
    '''Train the model'''
    args.train_batch_size = args.per_gpu_train_batch_size
    args.eval_batch_size = args.per_gpu_eval_batch_size

    train_sampler = RandomSampler(train_dataset)
    eval_sampler = SequentialSampler(eval_dataset)

    train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=args.train_batch_size, collate_fn=my_collate)
    eval_dataloader = DataLoader(eval_dataset, sampler=eval_sampler, batch_size=args.eval_batch_size, collate_fn=my_collate)


    parameters = filter(lambda param: param.requires_grad, model.parameters())
    optimizer = torch.optim.Adam(parameters, lr=args.learning_rate)

    # Train
    print("Started Training...")
    print("Num examples = {}".format(len(train_dataset)))
    print("Num Epochs = {}".format(args.num_train_epochs))
    print("Instantaneous batch size per GPU = {}".format(args.per_gpu_train_batch_size))

    all_eval_results = []

    set_seed(args)

    for epoch in range(args.num_train_epochs):
        model.train()
        train_loss = 0.0

        for step, batch in enumerate(train_dataloader):
            model.zero_grad()
            batch = tuple(t.to(args.device) for t in batch)
            inputs, labels = get_input_from_batch(args, batch)
            logit = model(**inputs)
            loss = F.cross_entropy(logit, labels)
            loss.backward()
            train_loss += loss.item()
            optimizer.step()

        model.eval()
        eval_loss = 0.0
        preds = None
        out_label_ids = None
        input_store = None
        
        for step, batch in enumerate(eval_dataloader):
            with torch.no_grad():
                batch = tuple(t.to(args.device) for t in batch)
                inputs, labels = get_input_from_batch(args, batch)
                logits = model(**inputs)
                loss = F.cross_entropy(logits, labels)
                eval_loss += loss.item()
    
                
                if preds is None:
                    inputs_indxs = [inputs['sentence'].detach().cpu().numpy()]
                    preds = logits.detach().cpu().numpy()
                    out_label_ids = labels.detach().cpu().numpy()
                    #print(len(inputs_indxs), len(logits), len(labels))
                else:
                    current_inputs = inputs['sentence'].detach().cpu().numpy()
                    inputs_indxs.append(current_inputs)
                    
                    preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)
                    out_label_ids = np.append(out_label_ids, labels.detach().cpu().numpy(), axis=0)
                    
        
        preds = np.argmax(preds, axis=1)
        result = compute_metrics(preds, out_label_ids)
    
        result['train_loss'] = train_loss/len(train_dataloader)
        result['eval_loss'] = eval_loss/len(eval_dataloader)
        result['epoch'] = epoch

        all_eval_results.append(result)
        print("Epoch: {}; train_loss: {}; eval_loss: {}; eval_acc: {}; eval_f1: {}".format(epoch + 1, np.round(train_loss/len(train_dataloader), 4), np.round(eval_loss/len(eval_dataloader), 4), np.round(result['acc'], 4), np.round(result['f1'], 4)))
    
    
    with open("preds.pkl", 'wb') as f:
        pickle.dump(preds, f, -1) 
        
    
    with open("inputs_indxs.pkl", 'wb') as f:
        pickle.dump(inputs_indxs, f, -1) 
        
    with open("out_label_ids.pkl", 'wb') as f:
        pickle.dump(out_label_ids, f, -1) 
            
    return all_eval_results

def compute_metrics(preds, labels):
    acc = accuracy_score(y_true=labels, y_pred=preds)
    f1 = f1_score(y_true=labels, y_pred=preds, average='macro')
    precision = precision_score(y_true=labels, y_pred=preds, average='macro')
    recall = recall_score(y_true=labels, y_pred=preds, average='macro')
    return {
        "acc": acc,
        "f1": f1,
        "precision": precision,
        "recall": recall
    }

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
args.device = device
print('Device is {}'.format(args.device))

# Set seed
set_seed(args)
# Load datasets and vocabs
train_dataset, test_dataset, word_vocab, dep_tag_vocab, pos_tag_vocab= load_datasets_and_vocabs(args)
args.dep_tag_vocab_size = len(dep_tag_vocab['stoi'])
#dep_tag_vocab
# Out:
# Device is cuda
# Read rest Train set: 1978
# Read rest Test set: 600
# Size of the train dataset: 3602
# Size of the test dataset: 1120
# Word vocab size: 3508

# %%
dep_tag_vocab
# Out:
# {'itos': ['<pad>',
#   '<unk>',
#   'det',
#   'nsubj',
#   'amod',
#   'conj',
#   'pobj',
#   'dobj',
#   'cc',
#   'prep',
#   'dep',
#   'poss',
#   'nn',
#   'advmod',
#   'rcmod',
#   'appos',
#   'cop',
#   'nsubjpass',
#   'num',
#   'partmod',
#   'aux',
#   'ccomp',
#   'advcl',
#   'predet',
#   'auxpass',
#   'infmod',
#   'xcomp',
#   'neg',
#   'mark',
#   'possessive',
#   'pcomp',
#   'iobj',
#   'parataxis',
#   'csubj',
#   'npadvmod',
#   'tmod',
#   'preconj',
#   'prt',
#   'expl',
#   'acomp',
#   'discourse',
#   'mwe'],
#  'stoi': defaultdict(<function __main__._default_unk_index()>,
#              {'<pad>': 0,
#               '<unk>': 1,
#               'det': 2,
#               'nsubj': 3,
#               'amod': 4,
#               'conj': 5,
#               'pobj': 6,
#               'dobj': 7,
#               'cc': 8,
#               'prep': 9,
#               'dep': 10,
#               'poss': 11,
#               'nn': 12,
#               'advmod': 13,
#               'rcmod': 14,
#               'appos': 15,
#               'cop': 16,
#               'nsubjpass': 17,
#               'num': 18,
#               'partmod': 19,
#               'aux': 20,
#               'ccomp': 21,
#               'advcl': 22,
#               'predet': 23,
#               'auxpass': 24,
#               'infmod': 25,
#               'xcomp': 26,
#               'neg': 27,
#               'mark': 28,
#               'possessive': 29,
#               'pcomp': 30,
#               'iobj': 31,
#               'parataxis': 32,
#               'csubj': 33,
#               'npadvmod': 34,
#               'tmod': 35,
#               'preconj': 36,
#               'prt': 37,
#               'expl': 38,
#               'acomp': 39,
#               'discourse': 40,
#               'mwe': 41,
#               'root': 1,
#               'punct': 1,
#               'number': 1,
#               'csubjpass': 1,
#               'quantmod': 1}),
#  'len': 42}

# %% [markdown]
# ## Prelim results
#
# | Metrics\Datasets      | Twitter | Restaurant | Laptop     |
# | :---        |    :----:   |  :----:|        ---: |
# | Precision      | 0.70       | 0.632 | 0.5950  |
# | Recall   | 0.60        | 0.582 | 0.6069     |
# | F1   | 0.623        | 0.573 | 0.5919     |
# | Accuracy   | 0.669        | 0.7366 | 0.6489     |

# %%
model = TextGraphAttentionNetwork(args, dep_tag_vocab['len']).to(args.device)
model
# Out:
# TextGraphAttentionNetwork(
#   (embed): Embedding(3508, 300)
#   (dropout): Dropout(p=0, inplace=False)
#   (tanh): Tanh()
#   (gate): Gating(
#     (linear): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#     )
#     (gate): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#     )
#   )
#   (rnn): GRU(300, 300, num_layers=2, batch_first=True, bidirectional=True)
#   (dep_embed): Embedding(42, 300)
#   (fc): Linear(in_features=300, out_features=600, bias=True)
#   (fcs): Sequential(
#     (0): Linear(in_features=1200, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features
# Epoch: 24; train_loss: 0.1763; eval_loss: 1.8235; eval_acc: 0.7348; eval_f1: 0.597
# Epoch: 25; train_loss: 0.1272; eval_loss: 1.9388; eval_acc: 0.742; eval_f1: 0.6339
# Epoch: 26; train_loss: 0.0969; eval_loss: 2.4597; eval_acc: 0.7304; eval_f1: 0.5904
# Epoch: 27; train_loss: 0.088; eval_loss: 2.5979; eval_acc: 0.7562; eval_f1: 0.6464
# Epoch: 28; train_loss: 0.1059; eval_loss: 1.553; eval_acc: 0.7188; eval_f1: 0.6422
# Epoch: 29; train_loss: 0.1569; eval_loss: 1.9616; eval_acc: 0.7429; eval_f1: 0.6275
# Epoch: 30; train_loss: 0.1141; eval_loss: 1.3177; eval_acc: 0.7509; eval_f1: 0.6378
# Best Eval result is:
# {'acc': 0.7875, 'f1': 0.686745152606497, 'precision': 0.7011585884353742, 'recall': 0.6772632129774987, 'train_loss': 0.5680371113616017, 'eval_loss': 0.5312552507434573, 'epoch': 2}

# %%
test_sentences = []

# %%
with open("preds.pkl", 'rb') as f:
    preds = pickle.load(f)
    
with open("inputs_indxs.pkl", 'rb') as f:
    inputs_indxs = pickle.load(f)

with open("out_label_ids.pkl", 'rb') as f:
    out_label_ids = pickle.load(f)

# %%
def i2token(sentence):
    sents = []
    for index in sentence:
        sents.append(word_vocab['itos'][index])
    
    sents = ' '.join(sents)
    return sents

flat_inputs = []

for item in inputs_indxs:
    for subitem in item:
        flat_inputs.append(subitem)
len(flat_inputs)


#sentiments_lookup = {'negative': 0, 'positive': 1, 'neutral': 2}

miss_classifications = []
correct_classifications = []

for i in range(len(flat_inputs)):
    index_to_token = i2token(flat_inputs[i])
    if out_label_ids[i]!=preds[i]:
        miss_classifications.append([index_to_token, out_label_ids[i], preds[i]])
    
    else:
        correct_classifications.append([index_to_token, out_label_ids[i], preds[i]])

# %%
miss_classifications
# Out:
# [['i love the drinks , esp lychee martini , and the food is also very good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['i [UNK] the people at go sushi , it never [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['try the rose roll ( not on menu ) . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['great food but the service was dreadful ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ["the sangria 's - [UNK] down . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   1],
#  ['how pretentious and inappropriate for mj grill to claim that it provides power lunch and dinners ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['how pretentious and inappropriate for mj grill to claim that it provides power lunch and dinners ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the staff should be a bit more friendly . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['two [UNK] steaks -- what a [UNK] ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['good food at the right price , what more can you ask for . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['entrees include classics like lasagna , fettuccine alfredo and chicken parmigiana . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['entrees include classics like lasagna , fettuccine alfredo and chicken parmigiana . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['entrees include classics like lasagna , fettuccine alfredo and chicken parmigiana . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['entrees include classics like lasagna , fettuccine alfredo and chicken parmigiana . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['i was highly disappointed by their service and food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['i was highly disappointed by their service and food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['i was [UNK] surprised at the taste . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['this particular location certainly [UNK] [UNK] meats . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the management was less than accomodating . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ["the food did take a few extra minutes to come , but the cute waiters ' jokes and friendliness made up for it . [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ["yes , they 're a bit more expensive then typical , but then again , so is their food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   0],
#  ['sandwiches , burgers and salads , like the lemon - dressed cobb , are classic successes . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['the waiters always look angry and even ignore their high - [UNK] regulars . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the steak melted in my mouth . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['our waiter was friendly and it is a shame that he did nt have a supportive staff to work with . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['even when the chef is not in the house , the food and service are right on target . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['anywhere else , the prices would be 3x as high ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ["i know real indian food and this was n't it . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   2],
#  ['desserts include flan and sopaipillas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['desserts include flan and sopaipillas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['desserts include flan and sopaipillas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the decor is [UNK] in a [UNK] japanese style restaurant . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['tiny restaurant with very fast service . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['what a difference , the service was very comforting and the food was better than average , but what really standed out was such a dynamic and extensive beer list .',
#   1,
#   0],
#  ['we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the music which is sometimes a little too heavy for my taste . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['there was only one waiter for the whole restaurant upstairs . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['a beautiful atmosphere , perfect for drinks and/or appetizers . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['a beautiful atmosphere , perfect for drinks and/or appetizers . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['my favs here are the tacos pastor and the tostada de tinga ... [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['my favs here are the tacos pastor and the tostada de tinga ... [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ["good food good wine that 's it . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   2],
#  ['well , it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks , and then tells us to chill out . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ["the absolute worst service i 've ever experienced and the food was below average ( when they actually gave people the meals they ordered ) . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ['the food is all - around good , with the rolls usually excellent and the sushi / sashimi not quite on the same level . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['[UNK] milk [UNK] gelato - have you ever in your life heard of anything so ridiculously wonderful ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['my friends and i stop here for pizza before [UNK] the [UNK] [UNK] [UNK] theater . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["it 's eaten with black vinegar and shredded ginger . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ["it 's eaten with black vinegar and shredded ginger . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ['but regulars know that the sandwiches are the real star here . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['i usually get one the vietnamese beef noodle soup . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  [") it 's not the best japanese restaurant in the east village , but it 's a pretty solid one for its [UNK] prices , and worth [UNK] [UNK] . [PAD]",
#   1,
#   0],
#  ['we were so happy with our food and were even more thrilled when we saw the bill . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['we were so happy with our food and were even more thrilled when we saw the bill . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['service is excellent , no wait , and you get a lot for the price . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['service is excellent , no wait , and you get a lot for the price . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['the food is so good and so popular that waiting can really be a nightmare . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['my wife and i recently visited the bistro for dinner and had a wonderful experience . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['my friend had a burger and i had these wonderful blueberry pancakes . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["i thought the food is n't cheap at all compared to chinatown . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   1],
#  ["we did n't know if we should order a drink or leave ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ['first walking in the place seemed to have great ambience . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ["everytime i go there i ca n't pick anything to eat and not because the menu is filled with great things to eat . [PAD] [PAD]",
#   0,
#   1],
#  ['half a chicken with a mountain of rice and beans for $ 6.25 . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['the service is perfect too nothing wrong in this italian / french restaurant [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['go for the seafood paella for two . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['host and hostess was quite rude . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ["the food was definitely good , but when all was said and done , i just could n't justify it for the price ( including 2 drinks , $ 100/person ) ...",
#   0,
#   2],
#  ["the banana pudding they serve has never seen an oven , the crabcakes are way over salted and don't get me started on the very greasy mac and cheese . [PAD] [PAD]",
#   0,
#   1],
#  ["the banana pudding they serve has never seen an oven , the crabcakes are way over salted and don't get me started on the very greasy mac and cheese . [PAD] [PAD]",
#   0,
#   1],
#  ["the banana pudding they serve has never seen an oven , the crabcakes are way over salted and don't get me started on the very greasy mac and cheese . [PAD] [PAD]",
#   0,
#   1],
#  ['jazz [UNK] had a nice [UNK] + she made us all get up to dance to shake some [UNK] to eat some more . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ["i 've come here for casual [UNK] as well as for a friend 's birthday and i always enjoy myself . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ["they have very quick service which is great when you do n't have much time . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   0],
#  ['the food is average : breakfast food , soups , salads , sandwiches , etc . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the food is average : breakfast food , soups , salads , sandwiches , etc . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the food is average : breakfast food , soups , salads , sandwiches , etc . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the food is average : breakfast food , soups , salads , sandwiches , etc . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the food is average : breakfast food , soups , salads , sandwiches , etc . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['if you are a [UNK] fan you will not be disappointed . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['great beer selection too , something like 50 beers . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['their brunch menu had something for everyone . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['i was highly disappointed by the food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['our waitress had apparently never tried any of the food , and there was no one to recommend any wine . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['our waitress had apparently never tried any of the food , and there was no one to recommend any wine . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['but dinner here is never disappointing , even if the prices are a bit over the top . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['how can hope to stay in business with service like this ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the manager then told us we could order from whatever menu we wanted but by that time we were so annoyed with the waiter and the resturant that we let and went some place else . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['the service was pretty poor all around , the food was well below average relative to the cost , and outside there is a crazy bum who harasses every customer who leaves the place . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the unfortunate lady next to us thought she had ordered a salad ( including asking for salad dressing ) and was instead given a quesedilla . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['the unfortunate lady next to us thought she had ordered a salad ( including asking for salad dressing ) and was instead given a quesedilla . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['the unfortunate lady next to us thought she had ordered a salad ( including asking for salad dressing ) and was instead given a quesedilla . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['chef [UNK] , always there if you need him , is a real [UNK] and a real [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['during busy [UNK] , i recommend that you make a reservation . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['when she complained , the waitress said , sorry . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['now called [UNK] sushi , sushi is ok . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ["the sashimi portion are big enough to appease most people , but i did n't like the fact they used artifical lobster meat . [PAD]",
#   1,
#   0],
#  ["the sashimi portion are big enough to appease most people , but i did n't like the fact they used artifical lobster meat . [PAD]",
#   0,
#   2],
#  ['the staff members are extremely friendly and even replaced my drink once when i dropped it outside . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['they have wheat crusted pizza made with really fresh and yummy ingredients . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ["it took 100 years for [UNK] to get around to making pizza ( at least i do n't think they ever made it before this [UNK] ... but it was worth the wait . [PAD] [PAD] [PAD]",
#   1,
#   0],
#  ["unfortunately , unless you live in the neighborhood , it 's not in a convenient location but is more like a hidden treasure . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   1],
#  ['they have waiters on the sidewalk trying to [UNK] you in which made us [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['it was our only opportunity to visit and wanted an authentic italian meal . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['ask for the round corner table next to the large window . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ["the other times i 've gone it 's romantic date heaven , you can walk in get a booth by the windows , be treated like a vip in a not - crowded place , with great food and service .",
#   2,
#   1],
#  ['if your looking for nasty high priced food with a dash of ghetto scenery cheap bx a$ $ this is the place to be ! ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['if your looking for nasty high priced food with a dash of ghetto scenery cheap bx a$ $ this is the place to be ! ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['if your looking for nasty high priced food with a dash of ghetto scenery cheap bx a$ $ this is the place to be ! ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ["my only complaint might be the fortune cookies - i 've never had a cookie predict bad luck for me before i visited kar . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   1],
#  ['at night the atmoshere changes [UNK] into this hidden jewel that is waiting to be discovered . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['i would only go for the coffee which is way better than [UNK] or the like . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['new hamburger with special sauce is ok - at least better than big mac ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['perfectly al dente pasta , not drowned in sauce -- generous portions . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['would you ever believe that when you complain about over an hour wait , when they tell you it will be 20 - 30 minutes , the manager tells the bartender to spill the drinks you just paid for ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['would you ever believe that when you complain about over an hour wait , when they tell you it will be 20 - 30 minutes , the manager tells the bartender to spill the drinks you just paid for ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['would you ever believe that when you complain about over an hour wait , when they tell you it will be 20 - 30 minutes , the manager tells the bartender to spill the drinks you just paid for ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['would you ever believe that when you complain about over an hour wait , when they tell you it will be 20 - 30 minutes , the manager tells the bartender to spill the drinks you just paid for ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the waitress came by to pick up the soy sauce while we were eating our lunch ! ! ! ! ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the waitress came by to pick up the soy sauce while we were eating our lunch ! ! ! ! ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the waitress came by to pick up the soy sauce while we were eating our lunch ! ! ! ! ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["so we sat at the bar , the bartender did n't seem like he wanted to be there . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ['they also have a great assortment of wraps if your not in the mood for traditional mediterranean fare . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['you will not be [UNK] by any of the choices in the menu . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['the [UNK] selection of wines covers a wide variety without being [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["in short the black sheep [UNK] itself from the midtown pub [UNK] with a look that 's a mix of [UNK] - bar [UNK] and [UNK] [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   1],
#  ['with all the mundane or mediocre places on 8th avenue it is nice to have one that is a step above in quaility and atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['with all the mundane or mediocre places on 8th avenue it is nice to have one that is a step above in quaility and atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['then she made a fuss about not being able to add 1 or 2 chairs on either end of the table for additional people . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['then she made a fuss about not being able to add 1 or 2 chairs on either end of the table for additional people . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ["after waiting for almost an hour , the waiter brusquely told us he 'd forgotten to give the kitchen our order . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   0],
#  ['give it a try , menu is typical french but varied . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['it was good , but none of the flavors wow . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the food was mediocre to be kind - the interior is small and average - the owners are a tag - team of unpleasantries - so rude and snotty i actually let out a hearty guffaw whilst dining .',
#   0,
#   2],
#  ['the food was mediocre to be kind - the interior is small and average - the owners are a tag - team of unpleasantries - so rude and snotty i actually let out a hearty guffaw whilst dining .',
#   2,
#   1],
#  ['i have been going to this restaurant for years , in the past the service was average and the food inconsistant . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['for about eleven bucks you get a gigantic burrito ( or tacos ) , margarita , and dessert . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["cuisine is billed as asian fusion - does n't meet the bill . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   2],
#  ["cuisine is billed as asian fusion - does n't meet the bill . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   2],
#  ["cuisine is billed as asian fusion - does n't meet the bill . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   2],
#  ['the space is traditional in feel . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['dishes denoted as " roy \'s classics " ( marked on the menu with asterisks ) are tried - and - true recipes , such as macadamia - crusted mahi mahi , or subtly sweet honey - mustard beef short ribs .',
#   1,
#   2],
#  ['dishes denoted as " roy \'s classics " ( marked on the menu with asterisks ) are tried - and - true recipes , such as macadamia - crusted mahi mahi , or subtly sweet honey - mustard beef short ribs .',
#   2,
#   1],
#  ['not only is the food authentic , but the staff here are practically off - the - boat , they are young and hip and know what they are doing when it comes to food and wine . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['not only is the food authentic , but the staff here are practically off - the - boat , they are young and hip and know what they are doing when it comes to food and wine . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['not only is the food authentic , but the staff here are practically off - the - boat , they are young and hip and know what they are doing when it comes to food and wine . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['not only is the food authentic , but the staff here are practically off - the - boat , they are young and hip and know what they are doing when it comes to food and wine . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ["i came to fresh expecting a great meal , and all i got was marginally so - so food served in a restaurant that was just so freezing we could n't enjoy eating . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   1],
#  ['creative dishes like king crab salad with passion fruit vinaigrette and fettuccine with grilled seafood in a rosemary - orange sauce are unexpected elements on an otherwise predictable bistro menu . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the lone argentine chorizo appetizer at $ 8.95 was a heavy fennel flavored italian sausage like the ones that sell for $ 2.99/lb at the store . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the lone argentine chorizo appetizer at $ 8.95 was a heavy fennel flavored italian sausage like the ones that sell for $ 2.99/lb at the store . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['i went in one day asking for a table for a group and was greeted by a very rude hostess . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['best chinese on the upper east , prompt delivery , good value . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['what can you say about a place where the waitress brings out the wrong entree , then verbally assaults your 80 year old grandmother and gives her lip about sending it back ( which she did politely , by the way ) .',
#   0,
#   1],
#  ["the dinner menu offers a variety of great entrees , including fresh seafood and huge steaks , there 's also a couple of non - meat alternatives . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ['this place has the strangest menu and the restaurants tries too hard to make fancy food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['this place has the strangest menu and the restaurants tries too hard to make fancy food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['we had a birthday party here recently and the food and service was amazing . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['waiting three hours before getting our entrees was a treat as well . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['what can you say about a place where the waitress brings out the wrong entree , then verbally assaults your 80 year old grandmother and gives her lip about sending it back ( which she did politely , by the way ) .',
#   2,
#   0],
#  ["all - time favorites include the big mac , chicken mcnuggets , filet - o - fish sandwich and mcdonald 's famous french fries ; lighter options like entree - sized salads are also available . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   2],
#  ["all - time favorites include the big mac , chicken mcnuggets , filet - o - fish sandwich and mcdonald 's famous french fries ; lighter options like entree - sized salads are also available . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ["the halibut cheek appetizer came with a generous portion of foie gras , but that 's about the only positive thing i can say about the meal . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ['meat - phobes are in luck with the extraordinary veggie burger , made from a distinctive blend of chickpeas , carrots and other vegetables and spices . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ["it 's a basic pizza joint , not much to look at , but the pizza is what i go for . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   2],
#  ['was her monday for lunch - was working on a film in the area - and found this rare jewel . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['the service was on point - what else you would expect from a [UNK] ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['menus feature seasonal picks , like sweet corn - foie gras brulee . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['menus feature seasonal picks , like sweet corn - foie gras brulee . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['15 % gratuity automatically added to the bill . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['[UNK] the blue bar area too . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['the prices are not terrible . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['and these are not small , wimpy fast food type burgers - these are real , full sized patties . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['and these are not small , wimpy fast food type burgers - these are real , full sized patties . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['my date and i both ordered the branzini and both felt the fish was very average . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['my date and i both ordered the branzini and both felt the fish was very average . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['go with the specials , and stay away from the salmon . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the decor is what initially got me in the door . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['chinatown definitely has better quality with cheaper prices . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['chinatown definitely has better quality with cheaper prices . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['atmosphere is a [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['excellent tapas at great prices , romantic , small but not overly crowed , excellent [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  
[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ["my chelsea 's impressive and creative menu includes modern , westernized japanese dishes such as foie gras unagi napolean , jap style hamburger steak , spicy cod roe spaghetti , black cod with miso base , and rack of lamb in black truffle sauce , to name a few . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
# ...
#   1,
#   2],
#  ["it does n't look like much on the outside , but the minute you walk inside , it 's a whole other atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   0],
#  ['stick to the items the place does best , brisket , ribs , wings , cajun shrimp is good , not great . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['we requested they re - slice the sushi , and it was returned to us in small cheese - like cubes . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   2],
#  ['the decoration was feeling like we was on the [UNK] , actually the street is part of that [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['the ground chickpea soup we sampled as a starter tasted somewhat thin . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ['the ground chickpea soup we sampled as a starter tasted somewhat thin . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['make more tables- perhaps a rooftop bar ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["my chelsea 's impressive and creative menu includes modern , westernized japanese dishes such as foie gras unagi napolean , jap style hamburger steak , spicy cod roe spaghetti , black cod with miso base , and rack of lamb in black truffle sauce , to name a few .",
#   2,
#   1],
#  ["my chelsea 's impressive and creative menu includes modern , westernized japanese dishes such as foie gras unagi napolean , jap style hamburger steak , spicy cod roe spaghetti , black cod with miso base , and rack of lamb in black truffle sauce , to name a few .",
#   2,
#   1],
#  ["highly recommended ... as stated , i have n't dined * in * the restaurant but stopped by there to pick up takeout and it seems a very relaxing place ; also , the bar looks nice . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ["being [UNK] [UNK] i know a thing or two about flan and this place serves one of the best ( i hope mom does n't read this ! ) . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   2],
#  ['been to the one in brooklyn for over 25 years , now i do nt have to go over the bridge for the best pizza .... [UNK] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ['good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["we recently spent new year 's eve at the restaurant , and had a great experience , from the wine to the dessert menu . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   0],
#  ["we recently spent new year 's eve at the restaurant , and had a great experience , from the wine to the dessert menu . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   2],
#  ['but , the filet mignon was not very good at all cocktail hour includes free appetizers ( nice non - sushi selection ) . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   1],
#  ["do n't get me wrong - sushi was good , just not fantastic . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   0],
#  ['it took about 2 1/2 hours to be served our 2 courses . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['who said go when the place is quiet during the day ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   0],
#  ['the comments about fried foods is correct ( below ) but the other dishes , including the lamb entree and many of the salads ( avocado shrimp ) were quite good .',
#   0,
#   1],
#  ['if you are here as a pre - show meal , hop in a cab and take the extra 10 minutes to go to the uptown location . [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["the best dessert , a chocolate and peanut butter tart , is n't particularly hawaiian , but it 's a small world when it comes to sweets . [PAD] [PAD] [PAD] [PAD]",
#   2,
#   1],
#  ['good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['a small , outdoor eating area makes for a private , comfortable space to study alone or meet up with friends . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   0],
#  ['the sauce is excellent ( very fresh ) with dabs of real mozzarella . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['we were seated promptly in close [UNK] to the dance floor . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ['for an appetizer , their calamari is a winner . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   1],
#  ["the new menu has a few creative items , they were smart enough to keep some of the old favorites ( but they raised the prices ) , the staff is friendly most of the time , but i must agree with the person that wrote about their favorite words : no , ca n't , sorry ... , boy , they wo n't bend the rules for anyone .",
#   0,
#   2],
#  ['i was especially impressed during the bday party when the waitstaff went above and beyond in helping me decorate and bring out a bday cake as well as offering prompt and friendly service to a 15 person party . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   2],
#  ["the food is just okay , and it 's almost not worth going unless you 're getting the pialla , which is the only dish that 's really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#
[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['i can say that the wraps , burgers and salads were all fresh , tasty and the mango margareta at $ 9 was well worth the money .',
#   1,
#   1],
#  ['i can say that the wraps , burgers and salads were all fresh , tasty and the mango margareta at $ 9 was well worth the money .',
#   1,
#   1],
#  ['i can say that the wraps , burgers and salads were all fresh , tasty and the mango margareta at $ 9 was well worth the money .',
#   1,
#   1],
#  ["the selection of food is excellent ( i 'm not used to having much choice at restaurants ) , and the atmosphere is great . [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ["the selection of food is excellent ( i 'm not used to having much choice at restaurants ) , and the atmosphere is great . [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ["the food did take a few extra minutes to come , but the cute waiters ' jokes and friendliness made up for it . [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['the food is great ( big selection , reasonable prices ) and the drinks are really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the food is great ( big selection , reasonable prices ) and the drinks are really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the food is great ( big selection , reasonable prices ) and the drinks are really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the food is great ( big selection , reasonable prices ) and the drinks are really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['only suggestion is that you skip the dessert , it was overpriced and fell short on taste . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['only suggestion is that you skip the dessert , it was overpriced and fell short on taste . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['the atmosphere is very nice , and a [UNK] [UNK] from the rest of the [UNK] mall . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['sandwiches , burgers and salads , like the lemon - dressed cobb , are classic successes . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the fajita we tried was tasteless and burned and the mole sauce was way too sweet . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['the fajita we tried was tasteless and burned and the mole sauce was way too sweet . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['i do nt know what some people who rave about this hot [UNK] are talking about . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['it is a hidden delight complete with a quaint bar and good food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['it is a hidden delight complete with a quaint bar and good food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the staff is very [UNK] and they look good too . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["stay with the roasted [UNK] and you 'll be fine . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['the atmosphere is warm , comfortable , artsy and [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the design is very intimate and romantic . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['most importantly , it is reasonably priced . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['food was decent , but not great . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the food was wonderful and [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the worst though was the taste . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['i can say that the wraps , burgers and salads were all fresh , tasty and the mango margareta at $ 9 was well worth the money .',
#   1,
#   1],
#  ['be sure to try the smoked trout ... lamb chops , veal chops , rabbit , the potato gratin , on and on and on ... [PAD] [PAD]',
#   1,
#   1],
#  ['be sure to try the smoked trout ... lamb chops , veal chops , rabbit , the potato gratin , on and on and on ... [PAD] [PAD]',
#   1,
#   1],
#  ['be sure to try the smoked trout ... lamb chops , veal chops , rabbit , the potato gratin , on and on and on ... [PAD] [PAD]',
#   1,
#   1],
#  ['be sure to try the smoked trout ... lamb chops , veal chops , rabbit , the potato gratin , on and on and on ... [PAD] [PAD]',
#   1,
#   1],
#  ['be sure to try the smoked trout ... lamb chops , veal chops , rabbit , the potato gratin , on and on and on ... [PAD] [PAD]',
#   1,
#   1],
#  ['we been there and we really enjoy the food , was areally great food , and the service was really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['we been there and we really enjoy the food , was areally great food , and the service was really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['we been there and we really enjoy the food , was areally great food , and the service was really good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['our waiter was friendly and it is a shame that he did nt have a supportive staff to work with . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['even when the chef is not in the house , the food and service are right on target . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['even when the chef is not in the house , the food and service are right on target . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the food was very good and i was pleasantly surprised to see so many vegan options . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the food was very good and i was pleasantly surprised to see so many vegan options . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['
[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["for the price you pay for the food here , you 'd expect it to be at least on par with other japanese restaurants .",
#   0,
#   0],
#  ["for the price you pay for the food here , you 'd expect it to be at least on par with other japanese restaurants .",
#   0,
#   0],
#  ['the bartenders and the managers are really nice and the decor is very comfy and laid - back , all the while being trendy .',
#   1,
#   1],
#  ['the bartenders and the managers are really nice and the decor is very comfy and laid - back , all the while being trendy .',
#   1,
#   1],
#  ['the bartenders and the managers are really nice and the decor is very comfy and laid - back , all the while being trendy .',
#   1,
#   1],
#  ['for a savory take on the soup and sandwich meal , try the hot and sour soup . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['for a savory take on the soup and sandwich meal , try the hot and sour soup . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['this bar has it all - great drinks , cool atmosphere , excellent service and delicious food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['this bar has it all - great drinks , cool atmosphere , excellent service and delicious food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['this bar has it all - great drinks , cool atmosphere , excellent service and delicious food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['this bar has it all - great drinks , cool atmosphere , excellent service and delicious food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['finally , i got [UNK] of the bad service , obnoxious [UNK] , and snotty back talk . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['everything is scrumptious , from the excellent service by cute waitresses , to the extremely lush atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['everything is scrumptious , from the excellent service by cute waitresses , to the extremely lush atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['everything is scrumptious , from the excellent service by cute waitresses , to the extremely lush atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["if you 're looking for authentic hong kong - style food , look no further . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['while their kitchen food is delicious , their sushi is out of this world . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['while their kitchen food is delicious , their sushi is out of this world . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['also , the [UNK] [UNK] with shrimp ( appetizer ) is [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['we ordered lamb which was perfectly cooked and tasted awesome . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['i especially like their soft shell crab sandwich with fries . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['great food , great drinks , nice dining atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['great food , great drinks , nice dining atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['great food , great drinks , nice dining atmosphere . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['sit back in one of those comfortable chairs . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['food portion was small and below average . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ["good food good wine that 's it . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['the staff was extremely friendly and pleasant . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["it 's traditional , simple italian food . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['in addition to great hot dogs , dotp has wonderful breakfast sandwiches that feature , in addition to great things like tator tots and english muffins , a delicious nj - based pork product know to us jersey girls and boys as taylor ham .',
#   1,
#   1],
#  ['in addition to great hot dogs , dotp has wonderful breakfast sandwiches that feature , in addition to great things like tator tots and english muffins , a delicious nj - based pork product know to us jersey girls and boys as taylor ham .',
#   1,
#   1],
#  ['in addition to great hot dogs , dotp has wonderful breakfast sandwiches that feature , in addition to great things like tator tots and english muffins , a delicious nj - based pork product know to us jersey girls and boys as taylor ham .',
#   1,
#   1],
#  ['in addition to great hot dogs , dotp has wonderful breakfast sandwiches that feature , in addition to great things like tator tots and english muffins , a delicious nj - based pork product know to us jersey girls and boys as taylor ham .',
#   1,
#   1],
#  ['in addition to great hot dogs , dotp has wonderful breakfast sandwiches that feature , in addition to great things like tator tots and english muffins , a delicious nj - based pork product know to us jersey girls and boys as taylor ham .',
#   1,
#   1],
#  ['in addition to great hot dogs , dotp has wonderful breakfast sandwiches that feature , in addition to great things like tator tots and english muffins , a delicious nj - based pork product know to us jersey girls and boys as taylor ham .',
#   1,
#   1],
#  ['well , it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks , and then tells us to chill out . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['well , it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks , and then tells us to chill out . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['well , it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks , and then tells us to chill out . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['not only is the service great , but forming conversation around a table is so easy beacuse the atmosphere can be both romantic and comfortable . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['not only is the service great , but forming conversation around a table is so easy beacuse the atmosphere can be both romantic and comfortable . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["the absolute worst service i 've ever experienced and the food was below average ( when they actually gave people the meals they ordered ) . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ["the absolute worst service i 've ever experienced and the food was below average ( when they actually gave people the meals they ordered ) . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ['the food is all - around good , with the rolls usually excellent and the sushi / sashimi not quite on the same level . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
# ...
#   0,
#   0],
#  ['had dinner here on a friday and the food was great . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['had dinner here on a friday and the food was great . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the comments about fried foods is correct ( below ) but the other dishes , including the lamb entree and many of the salads ( avocado shrimp ) were quite good .',
#   1,
#   1],
#  ['the comments about fried foods is correct ( below ) but the other dishes , including the lamb entree and many of the salads ( avocado shrimp ) were quite good .',
#   1,
#   1],
#  ['the comments about fried foods is correct ( below ) but the other dishes , including the lamb entree and many of the salads ( avocado shrimp ) were quite good .',
#   1,
#   1],
#  ["the room is a little plain , but it 's difficult to make such a small place exciting and i would not suggest that as a reason not to go . [PAD]",
#   0,
#   0],
#  ["the room is a little plain , but it 's difficult to make such a small place exciting and i would not suggest that as a reason not to go . [PAD]",
#   0,
#   0],
#  ['however , there is just something so great about being outdoors , in great landscaping , enjoying a casual drink that makes going to this place worthwhile . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['however , there is just something so great about being outdoors , in great landscaping , enjoying a casual drink that makes going to this place worthwhile . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['however , there is just something so great about being outdoors , in great landscaping , enjoying a casual drink that makes going to this place worthwhile . [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["do n't ever bother - the drinks were awful , but it was the people who work there that really made this the worst experience at dining . [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ["do n't ever bother - the drinks were awful , but it was the people who work there that really made this the worst experience at dining . [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ["do n't ever bother - the drinks were awful , but it was the people who work there that really made this the worst experience at dining . [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ["the best dessert , a chocolate and peanut butter tart , is n't particularly hawaiian , but it 's a small world when it comes to sweets . [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ["the best dessert , a chocolate and peanut butter tart , is n't particularly hawaiian , but it 's a small world when it comes to sweets . [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['a small , outdoor eating area makes for a private , comfortable space to study alone or meet up with friends . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["slow service , but when you 're hanging around with groups of 10 or 20 , who really [UNK] ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ['satay is one of those favorite haunts on washington where the service and food is always on the money . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['satay is one of those favorite haunts on washington where the service and food is always on the money . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['and all the [UNK] female [UNK] servers are cute too , which is always nice . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['after dinner i heard music playing and discovered that there is a lounge downstairs . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['the sauce is excellent ( very fresh ) with dabs of real mozzarella . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['very nice touch that very much [UNK] the place . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['for an appetizer , their calamari is a winner . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['prices even outside of restaurant week were great . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ["the new menu has a few creative items , they were smart enough to keep some of the old favorites ( but they raised the prices ) , the staff is friendly most of the time , but i must agree with the person that wrote about their favorite words : no , ca n't , sorry ... , boy , they wo n't bend the rules for anyone .",
#   1,
#   1],
#  ['i was especially impressed during the bday party when the waitstaff went above and beyond in helping me decorate and bring out a bday cake as well as offering prompt and friendly service to a 15 person party . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the service is great ( maybe even borderline nagging but at least you get attention ) , the desserts are excellent and the coffee is so very good ... [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the service is great ( maybe even borderline nagging but at least you get attention ) , the desserts are excellent and the coffee is so very good ... [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['while the smoothies are a little big for me , the fresh juices are the best i have ever had ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['two complaints- their appetizer selection stinks , it would be nice to get some mozzarella sticks on the menu . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ["several times and put up with the waiters ' bad [UNK] , knowing that their job is n't easy . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   0,
#   0],
#  ['the room is a gorgeous , bi - level space and the long bar perfect for a drink . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the room is a gorgeous , bi - level space and the long bar perfect for a drink . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['the guac is fresh , yet lacking flavor , we like to add our fresh salsa into it . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['the guac is fresh , yet lacking flavor , we like to add our fresh salsa into it . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['the atmosphere takes you to that place , the place many dream of . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['the chicken and falafel platters were nondescript combinations with fresh leaf salad . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['the chicken and falafel platters were nondescript combinations with fresh leaf salad . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ["it ' only open for lunch but the food is so good ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   2],
#  ["it ' only open for lunch but the food is so good ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['they are served on focacchia bread and are to die for . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ["its good to go there for drinks if you do n't want to get drunk because you 'll be lucky if you can get one drink an hour the service is so bad .",
#   0,
#   0],
#  ["its good to go there for drinks if you do n't want to get drunk because you 'll be lucky if you can get one drink an hour the service is so bad .",
#   2,
#   2],
#  ['creamy appetizers -- taramasalata , eggplant salad , and greek yogurt ( with cuccumber , dill , and garlic ) taste excellent when on warm pitas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['creamy appetizers -- taramasalata , eggplant salad , and greek yogurt ( with cuccumber , dill , and garlic ) taste excellent when on warm pitas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['creamy appetizers -- taramasalata , eggplant salad , and greek yogurt ( with cuccumber , dill , and garlic ) taste excellent when on warm pitas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['creamy appetizers -- taramasalata , eggplant salad , and greek yogurt ( with cuccumber , dill , and garlic ) taste excellent when on warm pitas . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['i have never in my life sent back food before , but i simply had to , and the waiter argued with me over this . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['i have never in my life sent back food before , but i simply had to , and the waiter argued with me over this . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ["i just had my first visit to this place and ca n't wait to go back and [UNK] work my way through the menu . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   2,
#   2],
#  ['i asked repeatedly what the status of the meal was and was pretty much grunted at by the unbelievably rude waiter . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['sweet [UNK] bartender is always happy and able to bring a smile to my friends a my [UNK] . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1],
#  ['i stopped by for some brunch today and had the vegan cranberry pancakes and some rice milk . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['i have eaten here on a different occasion - the food is mediocre for the prices . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ["i 'm looking forward to going back soon and [UNK] trying most everything on the menu ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#   1,
#   1],
#  ['how can they survive serving mediocre food at exorbitant prices ? ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['how can they survive serving mediocre food at exorbitant prices ? ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['the food was mediocre and the service was severely slow . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['the food was mediocre and the service was severely slow . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   2,
#   2],
#  ['anyway , the owner was fake . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   0,
#   0],
#  ['owner is pleasant and entertaining . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#   1,
#   1]]
